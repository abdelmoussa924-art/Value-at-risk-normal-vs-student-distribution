# %% [markdown]
# COMPARISON OF NORMAL AND STUDENT DISTRIBUTION
# ==========================================================================

# %%
#import of libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings

import scipy.stats as stats
from scipy.stats import norm, t, jarque_bera

warnings.filterwarnings("ignore")
plt.style.use("default")

# %%
#import of data and data munging
apple=pd.read_csv("apple.csv")
apple["Date"]=pd.to_datetime(apple["Date"])
apple.set_index("Date",inplace=True)
apple.sort_index(inplace=True)

#Calibrate on 2006-2007 calm period
apl=apple["2006-10-02":"2007-10-02"].dropna()
print(apl.head())
print("")
print(apl.tail())
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2006-10-02  10.728572  10.838572  10.614285  10.694285   7.239566  178159800
# 2006-10-03  10.635715  10.707143  10.455714  10.582857   7.164135  197677200
# 2006-10-04  10.585714  10.780000  10.451428  10.768572   7.289855  207270700
# 2006-10-05  10.647142  10.880000  10.590000  10.690000   7.236666  170970800
# 2006-10-06  10.631429  10.720000  10.544286  10.602858   7.177672  116739700
#
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2007-09-26  22.067142  22.142857  21.607143  21.824286  14.774095  243817000
# 2007-09-27  21.967142  22.074286  21.760000  22.071428  14.941398  164549700
# 2007-09-28  21.920000  22.085714  21.821428  21.924286  14.841787  153775300
# 2007-10-01  22.090000  22.487143  21.847143  22.334286  15.119342  209267100
# 2007-10-02  22.364286  22.655714  22.270000  22.635714  15.323395  198017400

# %%
#determine logreturn, its visualisation, mean mu, volatility sigma
apl["logreturn"]=np.log(apl["Close"]/apl["Close"].shift(1))
mu=apl["logreturn"].mean()
sigma=apl["logreturn"].std(ddof=1)
apl["logreturn"].hist(bins=50)
print(f"mean mu={mu:.2f} and volatility sigma={sigma:.2f}")
# Out:
# mean mu=0.00 and volatility sigma=0.02

# %% [markdown]
# Com: logreturns histogram looks like bell, mean mu=0.00 and  volatility sigma=0.02
# -->so we suppose that the distribution is normal

# %%
#determine density function pdf and cumulative function cdf and their visualisation, 
#calcul value at risk at 95% and its visualisation and expected shortfall ES
denapl=pd.DataFrame()
denapl["x"]=np.arange(-0.1,0.1,0.001)
denapl["PDF_norm"]=norm.pdf(denapl["x"],mu,sigma)
denapl["CDF_norm"]=norm.cdf(denapl["x"],mu,sigma)
alpha=0.05
VaR95_norm=norm.ppf(alpha,mu,sigma)
ES=mu-sigma*norm.pdf(norm.ppf(0.05))/alpha
print(f"normal Value at risk={VaR95_norm:.2f} and expected shortfall ES={ES:.2f}")
# Out:
# normal Value at risk=-0.03 and expected shortfall ES=-0.04

# %%
#Backtesting on crise year 2008, supposing the distribution is normal
apl08=apple["2007-12-31":"2008-12-31"].dropna()
apl08["logreturn"]=(np.log(apl08["Close"]/(apl08["Close"].shift(1)))).dropna()
apl08["violation"]=apl08["logreturn"]<VaR95_norm
nb_day=len(apl08)
nb_violation=apl08["violation"].sum()
violation_rate=(nb_violation/nb_day)*100
expected_rate=5 
print("==========normal backtest==========")
print(f"""number of trading day={nb_day:.2f}
number of violation={nb_violation:.2f}
violation rate={violation_rate:.2f}%
expected rate={expected_rate:.2f}%""")
#-->Output: normal violation rate=18.5%>expected rate=5%
if violation_rate>5:
    print(f"""violation rate={violation_rate:.2f}% > 5%,
          --> so the normal distribution under-estimate the risk""")
else:
      print("the normal distribution is adapted to these returns")
print("="*35)
print("")
# Out:
# ==========normal backtest==========
# number of trading day=254.00
# number of violation=47.00
# violation rate=18.50%
# expected rate=5.00%
# violation rate=18.50% > 5%,
#           --> so the normal distribution under-estimate the risk
# ===================================

# %% [markdown]
# Com: the normal distribution under-estimate the risk. We are going to verify about fat tails

# %%
#verify if there are fat tails
#jarque_bera
jb_stats,jb_pvalue=stats.jarque_bera(apl["logreturn"].dropna())
print(f"jb stats={jb_stats:.2f} and jb_pvalue ={jb_pvalue:.2f}")
#qq-plot
stats.probplot(apl["logreturn"], dist="norm", plot=plt)
# Out:
# jb stats=24.81 and jb_pvalue =0.00
# ((array([-2.77656829, -2.4747255 , -2.30335476, -2.18099319, -2.0845634 ,
#          -2.00433695, -1.93525503, -1.87433666, -1.81967137, -1.76995825,
#          -1.72426993, -1.68192103, -1.64239011, -1.60527085, -1.5702402 ,
#          -1.53703691, -1.50544658, -1.47529098, -1.44642028, -1.41870723,
#          -1.39204287, -1.36633307, -1.34149598, -1.31745993, -1.29416181,
#          -1.27154575, -1.249562  , -1.2281661 , -1.20731813, -1.1869821 ,
#          -1.16712546, -1.14771863, -1.1287347 , -1.11014907, -1.0919392 ,
#          -1.0740844 , -1.05656561, -1.03936522, -1.02246696, -1.00585573,
#          -0.98951752, -0.97343927, -0.9576088 , -0.94201475, -0.92664647,
#          -0.911494  , -0.89654796, -0.88179957, -0.86724053, -0.85286303,
#          -0.83865971, -0.82462359, -0.81074809, -0.79702695, -0.78345425,
#          -0.77002437, -0.75673195, -0.74357192, -0.73053942, -0.71762984,
#          -0.70483876, -0.69216198, -0.67959546, -0.66713536, -0.65477799,
#          -0.64251981, -0.63035742, -0.61828758, -0.60630714, -0.5944131 ,
#          -0.58260257, -0.57087274, -0.55922095, -0.54764459, -0.53614116,
#          -0.52470825, -0.51334351, -0.50204469, -0.49080961, -0.47963614,
#          -0.46852224, -0.45746591, -0.44646522, -0.4355183 , -0.42462332,
#          -0.41377852, -0.40298216, -0.39223258, -0.38152813, -0.37086722,
#          -0.36024829, -0.34966984, -0.33913037, -0.32862844, -0.31816263,
#          -0.30773155, -0.29733385, -0.2869682 , -0.27663329, -0.26632785,
#          -0.25605061, -0.24580035, -0.23557585, -0.22537592, -0.21519938,
#          -0.20504508, -0.19491188, -0.18479866, -0.1747043 , -0.16462771,
#          -0.15456781, -0.14452353, -0.13449381, -0.1244776 , -0.11447386,
#          -0.10448157, -0.0944997 , -0.08452723, -0.07456317, -0.0646065 ,
#          -0.05465623, -0.04471137, -0.03477093, -0.02483393, -0.01489938,
#          -0.0049663 ,  0.0049663 ,  0.01489938,  0.02483393,  0.03477093,
#           0.04471137,  0.05465623,  0.0646065 ,  0.07456317,  0.08452723,
#           0.0944997 ,  0.10448157,  0.11447386,  0.1244776 ,  0.13449381,
#           0.14452353,  0.15456781,  0.16462771,  0.1747043 ,  0.18479866,
#           0.19491188,  0.20504508,  0.21519938,  0.22537592,  0.23557585,
#           0.24580035,  0.25605061,  0.26632785,  0.27663329,  0.2869682 ,
#           0.29733385,  0.30773155,  0.31816263,  0.32862844,  0.33913037,
#           0.34966984,  0.36024829,  0.37086722,  0.38152813,  0.39223258,
#           0.40298216,  0.41377852,  0.42462332,  0.4355183 ,  0.44646522,
#           0.45746591,  0.46852224,  0.47963614,  0.49080961,  0.50204469,
#           0.51334351,  0.52470825,  0.53614116,  0.54764459,  0.55922095,
#           0.57087274,  0.58260257,  0.5944131 ,  0.60630714,  0.61828758,
#           0.63035742,  0.64251981,  0.65477799,  0.66713536,  0.67959546,
#           0.69216198,  0.70483876,  0.71762984,  0.73053942,  0.74357192,
#           0.75673195,  0.77002437,  0.78345425,  0.79702695,  0.81074809,
#           0.82462359,  0.83865971,  0.85286303,  0.86724053,  0.88179957,
#           0.89654796,  0.911494  ,  0.92664647,  0.94201475,  0.9576088 ,
#           0.97343927,  0.98951752,  1.00585573,  1.02246696,  1.03936522,
#           1.05656561,  1.0740844 ,  1.0919392 ,  1.11014907,  1.1287347 ,
#           1.14771863,  1.16712546,  1.1869821 ,  1.20731813,  1.2281661 ,
#           1.249562  ,  1.27154575,  1.29416181,  1.31745993,  1.34149598,
#           1.36633307,  1.39204287,  1.41870723,  1.44642028,  1.47529098,
#           1.50544658,  1.53703691,  1.5702402 ,  1.60527085,  1.64239011,
#           1.68192103,  1.72426993,  1.76995825,  1.81967137,  1.87433666,
#           1.93525503,  2.00433695,  2.0845634 ,  2.18099319,  2.30335476,
#           2.4747255 ,  2.77656829]),
#   array([-7.08228804e-02, -6.39277847e-02, -6.32681894e-02, -5.85420379e-02,
#          -5.31324445e-02, -5.26961845e-02, -4.19252418e-02, -3.51515835e-02,
#          -3.45864323e-02, -3.43497667e-02, -3.38654106e-02, -3.15511780e-02,
#          -2.98648283e-02, -2.98495358e-02, -2.59844408e-02, -2.42909153e-02,
#          -2.42150964e-02, -2.40568772e-02, -2.39651380e-02, -2.35305079e-02,
#          -2.32908144e-02, -2.30732427e-02, -2.28004498e-02, -2.23909495e-02,
#          -2.22331988e-02, -2.21886479e-02, -2.18950325e-02, -2.13788438e-02,
#          -1.96803478e-02, -1.95112467e-02, -1.91344045e-02, -1.81217682e-02,
#          -1.77696923e-02, -1.72101307e-02, -1.69683065e-02, -1.69660827e-02,
#          -1.64922113e-02, -1.59031296e-02, -1.50023449e-02, -1.48355872e-02,
#          -1.48308823e-02, -1.28787142e-02, -1.26385592e-02, -1.24481795e-02,
#          -1.23938564e-02, -1.23340864e-02, -1.18826569e-02, -1.16151128e-02,
#          -1.14976862e-02, -1.12394553e-02, -1.10586035e-02, -1.10482667e-02,
#          -1.09714444e-02, -1.09382919e-02, -1.09266208e-02, -1.04740588e-02,
#          -1.01381165e-02, -9.60346521e-03, -9.41748628e-03, -9.00045696e-03,
#          -8.96407139e-03, -8.77473673e-03, -8.47976018e-03, -8.42955325e-03,
#          -8.18513762e-03, -8.00553551e-03, -7.88903684e-03, -7.58264109e-03,
#          -7.32316681e-03, -7.29052228e-03, -7.14666502e-03, -6.68894923e-03,
#          -6.41998009e-03, -6.41188384e-03, -6.30703732e-03, -5.74129597e-03,
#          -5.70341225e-03, -5.63067920e-03, -5.38031808e-03, -5.34374531e-03,
#          -5.20393192e-03, -5.04590333e-03, -4.92776216e-03, -4.78918351e-03,
#          -4.69383198e-03, -4.54835458e-03, -4.46956765e-03, -4.32949045e-03,
#          -4.07713701e-03, -3.71630114e-03, -3.39555134e-03, -3.31210217e-03,
#          -3.27317780e-03, -3.19406704e-03, -2.89153620e-03, -2.88575333e-03,
#          -2.68011279e-03, -2.64323114e-03, -2.43681848e-03, -2.27652807e-03,
#          -2.19246965e-03, -2.12286909e-03, -1.67549139e-03, -1.62786034e-03,
#          -1.52614226e-03, -1.43905482e-03, -1.20162244e-03, -1.06492252e-03,
#          -1.05572701e-03, -3.47893539e-04, -3.40989964e-04, -1.08959211e-04,
#           9.95667106e-05,  1.17953867e-04,  1.22713606e-04,  1.24305169e-04,
#           2.23331099e-04,  3.02168167e-04,  3.48192417e-04,  5.53261416e-04,
#           9.58302799e-04,  1.30990688e-03,  1.57964861e-03,  1.64478355e-03,
#           2.10179895e-03,  2.49866285e-03,  2.55433096e-03,  2.68280628e-03,
#           2.79951189e-03,  3.18689107e-03,  3.22530869e-03,  3.37952530e-03,
#           3.46933368e-03,  3.47177298e-03,  3.83323396e-03,  4.07532009e-03,
#           4.29463817e-03,  4.33974751e-03,  4.92611834e-03,  5.05246398e-03,
#           5.28570439e-03,  5.45491468e-03,  5.50878107e-03,  5.53650358e-03,
#           5.68545316e-03,  5.84821712e-03,  6.22445436e-03,  6.38637595e-03,
#           6.40439105e-03,  6.53749694e-03,  7.05891146e-03,  7.19599172e-03,
#           7.67651809e-03,  7.72452515e-03,  7.74292596e-03,  7.87626983e-03,
#           7.93319971e-03,  8.06935666e-03,  8.17344509e-03,  9.03536290e-03,
#           9.20653942e-03,  9.78002905e-03,  9.98637659e-03,  9.98751057e-03,
#           1.05820247e-02,  1.05982126e-02,  1.07365894e-02,  1.08674347e-02,
#           1.09102331e-02,  1.09765144e-02,  1.09837415e-02,  1.12605350e-02,
#           1.16011275e-02,  1.16663763e-02,  1.20801893e-02,  1.22013302e-02,
#           1.25345640e-02,  1.26099398e-02,  1.29583447e-02,  1.31008640e-02,
#           1.34059379e-02,  1.35195790e-02,  1.38348432e-02,  1.39191638e-02,
#           1.45105770e-02,  1.46293106e-02,  1.46894381e-02,  1.53802100e-02,
#           1.60547974e-02,  1.62345573e-02,  1.70433511e-02,  1.71750936e-02,
#           1.73964641e-02,  1.74173351e-02,  1.76581163e-02,  1.79375888e-02,
#           1.79719868e-02,  1.79751545e-02,  1.83902270e-02,  1.85280144e-02,
#           1.85481845e-02,  1.87106377e-02,  1.91162831e-02,  1.91491279e-02,
#           1.91500704e-02,  1.93750868e-02,  2.01707545e-02,  2.13684471e-02,
#           2.14322676e-02,  2.19529406e-02,  2.20745307e-02,  2.23774759e-02,
#           2.34891015e-02,  2.38105750e-02,  2.42927372e-02,  2.43342665e-02,
#           2.44453585e-02,  2.46091419e-02,  2.50357161e-02,  2.54599905e-02,
#           2.57905100e-02,  2.58724533e-02,  2.61260196e-02,  2.64332919e-02,
#           2.69331883e-02,  2.70001924e-02,  2.73436110e-02,  2.75385905e-02,
#           2.82480016e-02,  2.85450729e-02,  3.03839031e-02,  3.17630195e-02,
#           3.25112295e-02,  3.32241058e-02,  3.59480910e-02,  3.68039514e-02,
#           3.73838227e-02,  3.76972460e-02,  3.79248963e-02,  3.79929199e-02,
#           4.01978535e-02,  4.19115755e-02,  4.28425522e-02,  4.29428406e-02,
#           4.67457800e-02,  4.75877895e-02,  4.79242150e-02,  5.56677781e-02,
#           5.81196391e-02,  6.17296619e-02,  7.97996995e-02,             nan])),
#  (np.float64(nan), np.float64(nan), np.float64(nan)))

# %% [markdown]
# Com: jb stats=24.81 and pvalue=0.00<0.5
# +
# qqplot lokks like S ===> there are fat tails

# %%
#choice of the good distribution
#kurtosis
kurt_exces=apl["logreturn"].kurtosis()
print(f"kurtosis excess ={kurt_exces:.2f} so kurtosis is {kurt_exces+3:.2f}")
# Out:
# kurtosis excess =1.58 so kurtosis is 4.58

# %% [markdown]
# Com: kurtosis is 4.58 so the adeuqate distribution is student one

# %%
#Calibrate student distribution
ld,loc_t,scale_t=stats.t.fit(apl["logreturn"].dropna())
VaR95_t=t.ppf(alpha,ld,loc_t,scale_t)
z=VaR95_t
ES_t=loc_t+scale_t*(-t.pdf(z,ld)/alpha)*(ld+z**2)/(ld-1)
print(f"student VaR95={VaR95_t:.2f} and expected shortfall={ES_t:.2f}")
# Out:
# student VaR95=-0.03 and expected shortfall=-0.16

# %%
#Student backtest on 2008 crisis year
apl08["t_violation"]=apl08["logreturn"]<VaR95_t
nb_t_violation=apl08["t_violation"].sum()
t_violation_rate=(nb_t_violation/nb_day)*100
print("")
print("==========student Backtest==========")
print(f"""number of trading day={nb_day}
number of student violation={nb_t_violation:.2f}
student violation rate={t_violation_rate:.2f}%
expectedet rate=5%""")
print("="*36)
# Out:
# ==========student Backtest==========
# number of trading day=254
# number of student violation=49.00
# student violation rate=19.29%
# expectedet rate=5%
# ====================================

# %%
#visualisation
fig,(axe1,axe2,axe3)=plt.subplots(3,1,figsize=(14,10))
#logreturn visualisation
apl["logreturn"].plot(ax=axe1,label="logreturn",alpha=1,kind='hist', bins=50)
axe1.plot(denapl["x"],denapl["PDF_norm"],label="PDF_norm")
axe1.set_title("logreturn visualisation")
axe1.set_ylabel("frequency")
axe1.legend(loc="best")
#probability density function visualisation
axe2.plot(denapl["x"],denapl["PDF_norm"],label="PDF_norm",color="red")
axe2.fill_between(denapl["x"],denapl["PDF_norm"], where=(denapl["x"]<=VaR95_norm),
                  color="red",label="5% tail", alpha=0.7)
axe2.axvline(VaR95_norm, linestyle="--", color="red", label=f"VaR95 norm ={VaR95_norm:.2f}")
axe2.set_title("density function visualisation")
axe2.legend(loc="best")
#Cumulative density function visualisation
axe3.plot(denapl["x"],denapl["CDF_norm"],label="CDF_norm", color="red")
axe3.set_title("Cumulative function visualisation")
axe3.set_ylabel("probability")
axe3.legend(loc="best")

#visualisation
denapl["CDF_t"]=t.cdf(denapl["x"],ld,loc_t,scale_t)
denapl["PDF_t"]=t.pdf(denapl["x"],ld,loc_t,scale_t)
axe1.plot(denapl["x"],denapl["PDF_t"],label="PDF_t", color="green")
axe1.legend()
axe2.plot(denapl["x"],denapl["PDF_t"],label="PDF_t", color="green")
axe2.fill_between(denapl["x"],denapl["PDF_t"], where=(denapl["x"]<=VaR95_t),
                  color="green", label=" 5% student tail")
axe2.axvline(VaR95_t,linestyle="--",color="green", label=f"VaR95_t={VaR95_t:.2f}")
axe2.legend()

axe3.plot(denapl["x"],denapl["CDF_t"],color="green",label="CDF_t")
axe3.axvline(VaR95_t,linestyle="--", color="green",label=f"VaR95_t = {VaR95_t}")
axe3.axvline(VaR95_norm,linestyle="--", color="red", label=f"VaR95_norm = {VaR95_norm}")
axe3.legend()
#stats.probplot(apl["logreturn"], dist="norm", plot=axe4)


plt.tight_layout()
plt.show()

# %%
#normal vs student backtest visualisation

apl08["violation_norm"] = apl08["logreturn"] < VaR95_norm
apl08["violation_t"] = apl08["logreturn"] < VaR95_t

fig, ax = plt.subplots(figsize=(15,5))
apl08["logreturn"].plot(ax=ax, label="logreturn", color="blue", alpha=1)

ax.axhline(VaR95_norm, lw=2, color="red", linestyle="--", label=f"VaR95 norm = {VaR95_norm:.4f}")
ax.axhline(VaR95_t, lw=2, color="green", linestyle="--", label=f"VaR95 student = {VaR95_t:.4f}")

ax.scatter(apl08.index[apl08["violation_norm"]], 
           apl08.loc[apl08["violation_norm"], "logreturn"], 
           color="red", label="normal violations", zorder=3)

ax.scatter(apl08.index[apl08["violation_t"]], 
           apl08.loc[apl08["violation_t"], "logreturn"], 
           color="green", marker="x", label="student violations", zorder=4)

ax.set_title("VaR95 Violations — Normal vs Student (2008)")
ax.legend()
plt.show()

# %% [markdown]
# HISTORICAL VAR
# ==========================================================================

# %%
#Historical VaR95: empirical quantile of historical logreturns (no distribution assumption)
VaR95_hist = apl["logreturn"].dropna().quantile(alpha)
ES_hist = apl["logreturn"][apl["logreturn"] <= VaR95_hist].mean()
print(f"historical VaR95={VaR95_hist:.4f} and expected shortfall ES={ES_hist:.4f}")
# Out:
# historical VaR95=-0.0299 and expected shortfall ES=-0.0464

# %%
#Historical VaR backtest on 2008 crisis year
apl08["violation_hist"] = apl08["logreturn"] < VaR95_hist
nb_hist_violation = apl08["violation_hist"].sum()
hist_violation_rate = (nb_hist_violation/nb_day)*100
print("==========historical backtest==========")
print(f"""number of trading day={nb_day}
number of violation={nb_hist_violation}
violation rate={hist_violation_rate:.2f}%
expected rate={expected_rate:.2f}%""")
if hist_violation_rate>5:
    print(f"violation rate={hist_violation_rate:.2f}% > 5%, --> the historical VaR (calibrated on the calm period) under-estimates the 2008 crisis risk")
else:
    print("the historical VaR is adapted to these returns")
print("="*40)
# Out:
# ==========historical backtest==========
# number of trading day=254
# number of violation=52
# violation rate=20.47%
# expected rate=5.00%
# violation rate=20.47% > 5%, --> the historical VaR (calibrated on the calm period) under-estimates the 2008 crisis risk
# ========================================

# %% [markdown]
# MONTE CARLO VAR
# ==========================================================================

# %%
#Monte Carlo VaR: simulate logreturns from the calibrated normal distribution (mu, sigma)
np.random.seed(42)
n_sim = 100000
sim_returns = np.random.normal(mu, sigma, n_sim)
VaR95_mc = np.quantile(sim_returns, alpha)
ES_mc = sim_returns[sim_returns <= VaR95_mc].mean()
print(f"Monte Carlo VaR95={VaR95_mc:.4f} and expected shortfall ES={ES_mc:.4f}")
# Out:
# Monte Carlo VaR95=-0.0320 and expected shortfall ES=-0.0410

# %%
#Monte Carlo VaR backtest on 2008 crisis year
apl08["violation_mc"] = apl08["logreturn"] < VaR95_mc
nb_mc_violation = apl08["violation_mc"].sum()
mc_violation_rate = (nb_mc_violation/nb_day)*100
print("==========Monte Carlo backtest==========")
print(f"""number of trading day={nb_day}
number of violation={nb_mc_violation}
violation rate={mc_violation_rate:.2f}%
expected rate={expected_rate:.2f}%""")
if mc_violation_rate>5:
    print(f"violation rate={mc_violation_rate:.2f}% > 5%, --> the Monte Carlo VaR (based on the normal assumption) under-estimates the 2008 crisis risk")
else:
    print("the Monte Carlo VaR is adapted to these returns")
print("="*40)
# Out:
# ==========Monte Carlo backtest==========
# number of trading day=254
# number of violation=47
# violation rate=18.50%
# expected rate=5.00%
# violation rate=18.50% > 5%, --> the Monte Carlo VaR (based on the normal assumption) under-estimates the 2008 crisis risk
# ========================================

# %% [markdown]
# VISUAL COMPARISON OF ALL VaR95 METHODS
# ==========================================================================

# %%
#visualisation: all 4 VaR95 (normal, student, historical, monte carlo) vs 2008 returns
fig, ax = plt.subplots(figsize=(15,5))
apl08["logreturn"].plot(ax=ax, label="logreturn", color="grey", alpha=0.8)

ax.axhline(VaR95_norm, lw=2, color="red", linestyle="--", label=f"VaR95 norm = {VaR95_norm:.4f}")
ax.axhline(VaR95_t, lw=2, color="green", linestyle="--", label=f"VaR95 student = {VaR95_t:.4f}")
ax.axhline(VaR95_hist, lw=2, color="orange", linestyle="--", label=f"VaR95 historical = {VaR95_hist:.4f}")
ax.axhline(VaR95_mc, lw=2, color="purple", linestyle="--", label=f"VaR95 monte carlo = {VaR95_mc:.4f}")

ax.set_title("VaR95 Comparison — Normal vs Student vs Historical vs Monte Carlo (2008)")
ax.legend()
plt.show()

print("Violation rate summary (2008):")
print(f"normal     : {violation_rate:.2f}%")
print(f"student    : {t_violation_rate:.2f}%")
print(f"historical : {hist_violation_rate:.2f}%")
print(f"monte carlo: {mc_violation_rate:.2f}%")
print(f"expected   : {expected_rate:.2f}%")
# Out:
# Violation rate summary (2008):
# normal     : 18.50%
# student    : 19.29%
# historical : 20.47%
# monte carlo: 18.50%
# expected   : 5.00%

# %% [markdown]
# MONTE CARLO - PATH SIMULATION VISUALISATION
# ==========================================================================

# %%
#Simulation of 1000 price paths over the 2008 horizon (nb_day steps), via geometric Brownian motion (logreturns ~ N(mu, sigma))
np.random.seed(42)
n_paths = 1000
n_steps = nb_day

sim_logreturns_paths = np.random.normal(mu, sigma, size=(n_steps, n_paths))
sim_cum_logreturns = np.cumsum(sim_logreturns_paths, axis=0)

S0 = apl["Close"].iloc[-1]
sim_price_paths = S0 * np.exp(sim_cum_logreturns)

colors = ["yellow", "red", "green", "blue"]
n_colors = len(colors)

fig, ax = plt.subplots(figsize=(15,6))
for i in range(n_paths):
    ax.plot(sim_price_paths[:, i], color=colors[i % n_colors], alpha=0.5, lw=0.5)

ax.plot(sim_price_paths.mean(axis=1), color="black", lw=2, label="mean path")
ax.set_title(f"Monte Carlo — {n_paths} simulated price paths over {n_steps} days")
ax.set_xlabel("days")
ax.set_ylabel("simulated price")
ax.legend()
plt.show()

# %% [markdown]
# Conclusion:
#
# at 95% (VaR95): both are roughly equivalent (-0.032 vs -0.031), Student doesn't bring much here, and even appears slightly "less conservative."
#
#
# In the true extreme tail (ES, or VaR99): Student captures the risk much better (-0.16 vs -0.04). This is where the Jarque-Bera test (fat tails confirmed) and the kurtosis=4.58 (vs 3 for normal) translate concretely into the results.
